# %% [markdown]
# <a href="https://colab.research.google.com/github/dyumnaa/langchain/blob/main/Introduction_to_Langchain.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Prerequsites

# %%
# !pip install -qU langchain langchain_community  langchain-huggingface  langchain-chroma langchain-text-splitters crawl4ai
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.3/67.3 kB 3.7 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 40.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 252.8/252.8 kB 18.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 611.1/611.1 kB 33.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 81.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 125.8/125.8 kB 11.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 313.2/313.2 kB 25.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 108.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 98.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.1/45.1 MB 20.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.0/278.0 kB 20.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 kB 4.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.8/194.8 kB 14.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 284.2/284.2 kB 17.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.9/94.9 kB 8.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 74.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.9/50.9 kB 4.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.6/101.6 kB 8.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.0/16.0 MB 94.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 567.4/567.4 kB 34.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.9/55.9 kB 4.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.3/79.3 kB 6.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 54.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 101.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 82.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 47.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 10.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 67.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.3/62.3 kB 5.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 459.8/459.8 kB 33.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 319.7/319.7 kB 26.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.0/72.0 kB 6.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.0/4.0 MB 87.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 452.6/452.6 kB 26.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 3.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 6.9 MB/s eta 0:00:00
#   Building wheel for pypika (pyproject.toml) ... done
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pydrive2 1.21.3 requires pyOpenSSL<=24.2.1,>=19.1.0, but you have pyopenssl 25.0.0 which is incompatible.

# %% [markdown]
# ## Documents
#
# Class for storing a piece of text and associated metadata.

# %%
from langchain_core.documents import Document

document = Document(
    page_content="Hello, world!",
    metadata={"source": "https://example.com"}
)

# %% [markdown]
# ## Document Loaders
#
# DocumentLoaders load data into the standard LangChain Document format.
#
# [Different Document Loaders](https://python.langchain.com/docs/integrations/document_loaders/)

# %%
import re

from bs4 import BeautifulSoup
from langchain_community.document_loaders import RecursiveUrlLoader




loader = RecursiveUrlLoader("https://en.wikipedia.org/wiki/Thangal_Kunju_Musaliar_College_of_Engineering", max_depth=2,
)
documents_ = loader.load()
print(documents_)
# Out:
# [Document(metadata={'source': 'https://en.wikipedia.org/wiki/Thangal_Kunju_Musaliar_College_of_Engineering', 'content_type': 'text/html; charset=UTF-8', 'title': 'Thangal Kunju Musaliar College of Engineering - Wikipedia', 'language': 'en'}, page_content='<!DOCTYPE html>\n<html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-custom-font-size-clientpref-1 vector-feature-appearance-pinned-clientpref-1 vector-feature-night-mode-enabled skin-theme-clientpref-day vector-sticky-header-enabled vector-toc-available" lang="en" dir="ltr">\n<head>\n<meta charset="UTF-8">\n<title>Thangal Kunju Musaliar College of Engineering - Wikipedia</title>\n<script>(function(){var className="client-js vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-custom-font-size-clientpref-1 vector-feature-appearance-pinned-clientpref-1 vector-feature-night-mode-enabled skin-theme-clientpref-day vector-sticky-header-enabled vector-toc-available";var cookie=document.cookie.match(/(?:^|; )enwikimwclientpreferences=([^;]+)/);if(cookie){cookie[1].split(\'%2C\').forEach(function(pref){className=className.replace(new RegExp(\'(^| )\'+pref.replace(/-clientpref-\\w+$|[^\\w-]+/g,\'\')+\'-clientpref-\\\\w+( |$)\'),\'$1\'+pref+\'$2\');});}document.documentElement.className=className;}());RLCONF={"wgBreakFrames":false,"wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgRequestId":"b3fa38f8-2f82-4b8b-b610-66f0b79e6d96","wgCanonicalNamespace":"","wgCanonicalSpecialPageName":false,"wgNamespaceNumber":0,"wgPageName":"Thangal_Kunju_Musaliar_College_of_Engineering","wgTitle":"Thangal Kunju Musaliar College of Engineering","wgCurRevisionId":1271980861,"wgRevisionId":1271980861,"wgArticleId":2166451,"wgIsArticle":true,"wgIsRedirect":false,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["Pages using gadget WikiMiniAtlas","All articles with dead external links","Articles with dead external links from June 2018","Articles with permanently dead external links","Articles with short description","Short description is different from Wikidata","Use Indian English from December 2013","All Wikipedia articles written in Indian English","Use dmy dates from February 2021","Coordinates on Wikidata","Articles using infobox university","Articles needing cleanup from August 2019","All pages needing cleanup","Commons category link from Wikidata","Engineering colleges in Kollam","APJ Abdul Kalam Technological University","Science and technology in Kollam"],"wgPageViewLanguage":"en","wgPageContentLanguage":"en","wgPageContentModel":"wikitext","wgRelevantPageName":"Thangal_Kunju_Musaliar_College_of_Engineering","wgRelevantArticleId":2166451,"wgIsProbablyEditable":true,"wgRelevantPageIsProbablyEditable":true,"wgRestrictionEdit":[],"wgRestrictionMove":[],"wgNoticeProject":"wikipedia","wgCiteReferencePreviewsActive":false,"wgFlaggedRevsParams":{"tags":{"status":{"levels":1}}},"wgMediaViewerOnClick":true,"wgMediaViewerEnabledByDefault":true,"wgPopupsFlags":0,"wgVisualEditor":{"pageLanguageCode":"en","pageLanguageDir":"ltr","pageVariantFallbacks":"en"},"wgMFDisplayWikibaseDescriptions":{"search":true,"watchlist":true,"tagline":false,"nearby":true},"wgWMESchemaEditAttemptStepOversample":false,"wgWMEPageLength":10000,"wgCoordinates":{"lat":8.91388888888889,"lon": ...

# %% [markdown]
# ## Text Splitters
#
# - Handling non-uniform document lengths: Real-world document collections often contain texts of varying sizes. Splitting ensures consistent processing across all documents.
# - Overcoming model limitations: Many embedding models and language models have maximum input size constraints. Splitting allows us to process documents that would otherwise exceed these limits.
#
# [Different HTML Splitters](https://python.langchain.com/docs/how_to/split_html/)

# %%
url = "https://en.wikipedia.org/wiki/Thangal_Kunju_Musaliar_College_of_Engineering"
from langchain_text_splitters import HTMLHeaderTextSplitter

headers_to_split_on = [
    ("h1", "Main Title"),   # Page title
    ("h2", "Section"),      # Major sections
    ("h3", "Subsection"),   # Subsections within major sections
    ("h4", "Sub-subsection") # Further nested sections
]

html_splitter = HTMLHeaderTextSplitter(headers_to_split_on)
html_header_splits = html_splitter.split_text_from_url(url)

print(html_header_splits)
# Out:
# [Document(metadata={}, page_content='Jump to content  \nMain menu  \nMain menu  \nmove to sidebar  \nhide  \nNavigation  \nMain page  \nContents  \nCurrent events  \nRandom article  \nAbout Wikipedia  \nContact us  \nContribute  \nHelp  \nLearn to edit  \nCommunity portal  \nRecent changes  \nUpload file  \nSpecial pages  \nSearch  \nSearch  \nAppearance  \nDonate  \nCreate account  \nLog in  \nPersonal tools  \nDonate  \nCreate account  \nLog in  \nPages for logged out editors  \nlearn more  \nContributions  \nTalk  \nCentralNotice'), Document(metadata={'Section': 'Contents'}, page_content='Contents'), Document(metadata={}, page_content='move to sidebar  \nhide  \n(Top)  \n1  \nHistory  \n2  \nCampus  \n3  \nOrganisation and administration  \nToggle Organisation and administration subsection  \n3.1  \nGovernance  \n3.2  \nDepartments  \n3.3  \nFacilities  \n4  \nAcademics  \nToggle Academics subsection  \n4.1  \nAccreditation and affiliation  \n4.2  \nAdmission  \n4.3  \nSports  \n5  \nStudent life  \nToggle Student life subsection  \n5.1  \nTEDxTKMCE  \n6  \nAlumni  \n7  \nSee also  \n8  \nReferences  \n9  \nExternal links  \nToggle the table of contents  \nThangal Kunju Musaliar College of Engineering  \n2 languages  \nമലയാളം  \nதமிழ்  \nEdit links  \nArticle  \nTalk  \nEnglish  \nRead  \nEdit  \nView history  \nTools  \nTools  \nmove to sidebar  \nhide  \nActions  \nRead  \nEdit  \nView history  \nGeneral  \nWhat links here  \nRelated changes  \nUpload file  \nPermanent link  \nPage information  \nCite this page  \nGet shortened URL  \nDownload QR code  \nPrint/export  \nDownload as PDF  \nPrintable version  \nIn other projects  \nWikimedia Commons  \nWikidata item  \nAppearance  \nmove to sidebar  \nhide  \n:  \nCoordinates  \n.mw-parser-output .geo-default,.mw-parser-output .geo-dms,.mw-parser-output .geo-dec{display:inline}.mw-parser-output .geo-nondefault,.mw-parser-output .geo-multi-punct,.mw-parser-output .geo-inline-hidden{display:none}.mw-parser-output .longitude,.mw-parser-output .latitude{white-space:nowrap}  \n8°54′50″N  \n76°37′57″E  \n\ufeff / \ufeff  \n8.91389°N 76.63250°E  \n\ufeff /  \n8.91389; 76.63250  \nFrom Wikipedia, the free encyclopedia  \nesi <esi:include src="/esitest-fa8a495983347898/content" />  \nEducational institute in Kerala, India  \n.mw-parser-output .infobox-subbox{padding:0;border:none;margin:-3px;width:auto;min-width:100%;font-size:100%;clear:none;float:none;background-color:transparent}.mw-parser-output .infobox-3cols-child{margin:auto}.mw-parser-output .infobox .navbar{font-size:100%}@media screen{html.skin-theme-clientpref-night .mw-parser-output .infobox-full-data:not(.notheme)>div:not(.notheme)[style]{background:#1f1f23!important;color:#f8f9fa}}@media screen and (prefers-color-scheme:dark){html.skin-theme-clientpref-os .mw-parser-output .infobox-full-data:not(.notheme) div:not(.notheme){background:#1f1f23!important;color:#f8f9fa}}@media(min-width:640px){body.skin--responsive .mw-parser-output .infobox-table{display:table!important}body.skin--responsive .mw-parser-output .infobox-table>caption{display:table-caption!important}body.skin--responsive .mw-parser-output .infobox-table>tbody{display:table-row-group}body.skin--responsive .mw-parser-output .infobox-table tr{display:table-row!important}body.skin--responsive .mw-parser-output .infobox-table th,body.skin--responsive .mw-parser-output .infobox-table td{padding-left:inherit;padding-right:inherit}}  \nThangal Kunju Musaliar College of Engineering (Autonomous)  \nType  \nGovernment-Aided Autonomous Engineering College  \nEstablished  \n3\xa0July 1958  \n; 66 years ago  \n( )  \n1958-07-03  \nFounder  \nThangal Kunju Musliar  \nAffiliation  \nUniversities (Since 1958)  \n1.   (Since 2015)  \nAPJ Abdul Kalam Technological University  \n2.   (1958-2015)  \nUniversity of Kerala  \nChairman  \nT. K. Shahal Hassan Musaliar  \nPrincipal  \nT. A. Shahul Hameed  \nAcademic staff  \n200  \nAdministrative staff  \n500  \nStudents  \n4000  \nLo ...

# %% [markdown]
# ## Crawling Tools

# %% [markdown]
# https://github.com/unclecode/crawl4ai

# %%
# !crawl4ai-setup
# Out:
# [INIT].... → Running post-installation setup...
# [INIT].... → Installing Playwright browsers...
# Installing dependencies...
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Get:3 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Hit:4 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:5 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:6 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease [18.1 kB]
# Get:7 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease [24.3 kB]
# Get:8 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Hit:9 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:10 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [1,375 kB]
# Get:11 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy/main amd64 Packages [33.6 kB]
# Get:12 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [2,677 kB]
# Get:13 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Get:14 http://security.ubuntu.com/ubuntu jammy-security/restricted amd64 Packages [3,798 kB]
# Get:15 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy/main amd64 Packages [46.8 kB]
# Get:16 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1,533 kB]
# Get:17 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [3,000 kB]
# Get:18 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [2,692 kB]
# Get:19 https://r2u.stat.illinois.edu/ubuntu jammy/main all Packages [8,753 kB]
# Fetched 24.3 MB in 4s (5,411 kB/s)
# Reading package lists... Done
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# fonts-liberation is already the newest version (1:1.07.4-11).
# libasound2 is already the newest version (1.2.6.1-1ubuntu1).
# libasound2 set to manually installed.
# libatk-bridge2.0-0 is already the newest version (2.38.0-3).
# libatk-bridge2.0-0 set to manually installed.
# libatk1.0-0 is already the newest version (2.36.0-3build1).
# libatk1.0-0 set to manually installed.
# libatspi2.0-0 is already the newest version (2.44.0-3).
# libatspi2.0-0 set to manually installed.
# libcairo2 is already the newest version (1.16.0-5ubuntu2).
# libcairo2 set to manually installed.
# libfontconfig1 is already the newest version (2.13.1-4.2ubuntu5).
# libfontconfig1 set to manually installed.
# libxcb1 is already the newest version (1.14-3ubuntu3).
# libxcb1 set to manually installed.
# libxcomposite1 is already the newest version (1:0.4.5-1build2).
# libxcomposite1 set to manually installed.
# libxdamage1 is already the newest version (1:1.1.5-2build2).
# libxdamage1 set to manually installed.
# libxext6 is already the newest version (2:1.3.4-1build1).
# libxfixes3 is already the newest version (1:6.0.0-1).
# libxfixes3 set to manually installed.
# libxkbcommon0 is already the newest version (1.4.0-1).
# libxkbcommon0 set to manually installed.
# libxrandr2 is already the newest version (2:1.5.2-1build1).
# libxrandr2 set to manually installed.
# libcups2 is already the newest version (2.4.1op1-1ubuntu4.11).
# libcups2 set to manually installed.
# libdbus-1-3 is already the newest version (1.12.20-2ubuntu4.1).
# libdbus-1-3 set to manually installed.
# libdrm2 is already the newest version (2.4.113-2~ubuntu0.22.04.1).
# libdrm2 set to manually installed.
# libfreetype6 is already the newest version (2.11.1+dfsg-1ubuntu0.2).
# libfreetype6 set to manually installed.
# libgbm1 is already the newest version (23.2.1-1ubuntu3.1~22.04.3).
# libgbm1 set to manually installed.
# libglib2.0-0 is already the newest version (2.72.4-0ubuntu2.4).
# libglib2.0-0 set to manually installed.
# libnspr4 is already the newest version (2:4.35-0ubuntu0.22.04.1).
# libnspr4 set to manually installed.
# libnss3 is already the newest version (2:3.98-0ubuntu0.22.04.2).
# libnss3 set to manually installed.
# libpango-1.0-0 is already the newest version (1.50.6+ds-2ubuntu1).
# libpango-1.0-0 set to manually installed.
# libwayland-client0 is already the newest version (1.20.0-1ubuntu0.1).
# libwayland-client0 set to manually installed.
# libx11-6 is already the newest version (2:1.7.5-1ubuntu0.3).
# libx11-6 set to manually installed.
# The following additional packages will be installed:
#   libfontenc1 libxfont2 libxkbfile1 x11-xkb-utils xfonts-encodings xfonts-utils xserver-common
# Recommended packages:
#   fonts-ipafont-mincho fonts-tlwg-loma xfonts-base
# The following NEW packages will be installed:
#   fonts-freefont-ttf fonts-ipafont-gothic fonts-noto-color-emoji fonts-tlwg-loma-otf fonts-unifont
#   fonts-wqy-zenhei libfontenc1 libxfont2 libxkbfile1 x11-xkb-utils xfonts-cyrillic xfonts-encodings
#   xfonts-scalable xfonts-utils xserver-common xvfb
# 0 upgraded, 16 newly installed, 0 to remove and 29 not upgraded.
# Need to get 29.7 MB of archives.
# After this operation, 71.4 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-ipafont-gothic all 00303-21ubuntu1 [3,513 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-freefont-ttf all 20120503-10build1 [2,388 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 fonts-noto-color-emoji all 2.047-0ubuntu0.22.04.1 [10.0 MB]
# Get:4 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-tlwg-loma-otf all 1:0.7.3-1 [107 kB]
# Get:5 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-unifont all 1:14.0.01-1 [3,551 kB]
# Get:6 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-wqy-zenhei all 0.9.45-8 [7,472 kB]
# Get:7 http://archive.ubuntu.com/ubuntu jammy/main amd64 libfontenc1 amd64 1:1.1.4-1build3 [14.7 kB]
# Get:8 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxfont2 amd64 1:2.0.5-1build1 [94.5 kB]
# Get:9 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxkbfile1 amd64 1:1.1.0-1build3 [71.8 kB]
# Get:10 http://archive.ubuntu.com/ubuntu jammy/main amd64 x11-xkb-utils amd64 7.7+5build4 [172 kB]
# Get:11 http://archive.ubuntu.com/ubuntu jammy/main amd64 xfonts-encodings all 1:1.0.5-0ubuntu2 [578 kB]
# Get:12 http://archive.ubuntu.com/ubuntu jammy/main amd64 xfonts-utils amd64 1:7.7+6build2 [94.6 kB]
# Get:13 http://archive.ubuntu.com/ubuntu jammy/universe amd64 xfonts-cyrillic all 1:1.0.5 [386 kB]
# Get:14 http://archive.ubuntu.com/ubuntu jammy/main amd64 xfonts-scalable all 1:1.0.3-1.2ubuntu1 [306 kB]
# Get:15 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 xserver-common all 2:21.1.4-2ubuntu1.7~22.04.13 [29.1 kB]
# Get:16 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 xvfb amd64 2:21.1.4-2ubuntu1.7~22.04.13 [863 kB]
# Fetched 29.7 MB in 3s (9,135 kB/s)
# Selecting previously unselected package fonts-ipafont-gothic.
# (Reading database ... 125044 files and directories currently installed.)
# Preparing to unpack .../00-fonts-ipafont-gothic_00303-21ubuntu1_all.deb ...
# Unpacking fonts-ipafont-gothic (00303-21ubuntu1) ...
# Selecting previously unselected package fonts-freefont-ttf.
# Preparing to unpack .../01-fonts-freefont-ttf_20120503-10build1_all.deb ...
# Unpacking fonts-freefont-ttf (20120503-10build1) ...
# Selecting previously unselected package fonts-noto-color-emoji.
# Preparing to unpack .../02-fonts-noto-color-emoji_2.047-0ubuntu0.22.04.1_all.deb ...
# Unpacking fonts-noto-color-emoji (2.047-0ubuntu0.22.04.1) ...
# Selecting previously unselected package fonts-tlwg-loma-otf.
# Preparing to unpack .../03-fonts-tlwg-loma-otf_1%3a0.7.3-1_all.deb ...
# Unpacking fonts-tlwg-loma-otf (1:0.7.3-1) ...
#
downloaded to /root/.cache/ms-playwright/chromium_headless_shell-1155
# [COMPLETE] ● Playwright installation completed successfully.
# [INIT].... → Starting database initialization...
# [COMPLETE] ● Database backup created at: /root/.crawl4ai/crawl4ai.db.backup_20250316_143908
# [INIT].... → Starting database migration...
# [COMPLETE] ● Migration completed. 0 records processed.
# [COMPLETE] ● Database initialization completed successfully.
# [COMPLETE] ● Post-installation setup completed!

# %%
from langchain.document_loaders.base import BaseLoader
from langchain.docstore.document import Document
from crawl4ai import AsyncWebCrawler, BrowserConfig
import asyncio

class Crawl4AILoader(BaseLoader):
    def __init__(self, start_url: str, browser_config: BrowserConfig = None):
        """
        Initialize the Crawl4AI document loader.

        Args:
            start_url (str): The URL to start crawling from.
            browser_config (BrowserConfig, optional): Optional browser configuration for crawl4ai.
        """
        self.start_url = start_url
        self.browser_config = browser_config
        self._crawler = AsyncWebCrawler(config=browser_config)

    async def aload(self) -> list[Document]:
        """
        Asynchronously load documents using crawl4ai.

        Returns:
            A list of Document objects containing the crawled content and metadata.
        """
        # Start the asynchronous crawler.
        await self._crawler.start()

        # Crawl the provided URL to fetch content.
        results = await self._crawler.arun(self.start_url)
        metadata = {"url": results.url}
        content = results.markdown

        # Close the crawler to free resources.
        await self._crawler.close()

        # Wrap the fetched content in a Document object.
        return [Document(page_content=content, metadata=metadata)]

# Asynchronous main function to test the loader.
async def main():
    loader = Crawl4AILoader("https://en.wikipedia.org/wiki/Thangal_Kunju_Musaliar_College_of_Engineering")
    docs = await loader.aload()
    for doc in docs:
        # Display the URL and a snippet of the content.
        print(f"URL: {doc.metadata['url']}")
        print(f"Content: {doc.page_content}...")  # Show first 200 characters for brevity.

loop = asyncio.get_running_loop()
task = loop.create_task(main())
await task
# Out:
# [INIT].... → Crawl4AI 0.5.0.post4
# [FETCH]... ↓ https://en.wikipedia.org/wiki/Thangal_Kunju_Musali... | Status: True | Time: 1.23s
# [SCRAPE].. ◆ https://en.wikipedia.org/wiki/Thangal_Kunju_Musali... | Time: 0.398s
# [COMPLETE] ● https://en.wikipedia.org/wiki/Thangal_Kunju_Musali... | Status: True | Total: 1.65s
# URL: https://en.wikipedia.org/wiki/Thangal_Kunju_Musaliar_College_of_Engineering
# Content: [Jump to content](https://en.wikipedia.org/wiki/Thangal_Kunju_Musaliar_College_of_Engineering#bodyContent)
# Main menu
# Main menu
# move to sidebar hide
# Navigation
#   * [Main page](https://en.wikipedia.org/wiki/Main_Page "Visit the main page \[alt-shift-z\]")
#   * [Contents](https://en.wikipedia.org/wiki/Wikipedia:Contents "Guides to browsing Wikipedia")
#   * [Current events](https://en.wikipedia.org/wiki/Portal:Current_events "Articles related to current events")
#   * [Random article](https://en.wikipedia.org/wiki/Special:Random "Visit a randomly selected article \[alt-shift-x\]")
#   * [About Wikipedia](https://en.wikipedia.org/wiki/Wikipedia:About "Learn about Wikipedia and how it works")
#   * [Contact us](https://en.wikipedia.org/wiki/Wikipedia:Contact_us "How to contact Wikipedia")
#
#
# Contribute
#   * [Help](https://en.wikipedia.org/wiki/Help:Contents "Guidance on how to use and edit Wikipedia")
#   * [Learn to edit](https://en.wikipedia.org/wiki/Help:Introduction "Learn how to edit Wikipedia")
#   * [Community portal](https://en.wikipedia.org/wiki/Wikipedia:Community_portal "The hub for editors")
#   * [Recent changes](https://en.wikipedia.org/wiki/Special:RecentChanges "A list of recent changes to Wikipedia \[alt-shift-r\]")
#   * [Upload file](https://en.wikipedia.org/wiki/Wikipedia:File_upload_wizard "Add images or other media for use on Wikipedia")
#   * [Special pages](https://en.wikipedia.org/wiki/Special:SpecialPages)
#
#
# [ ![](https://en.wikipedia.org/static/images/icons/wikipedia.png) ![Wikipedia](https://en.wikipedia.org/static/images/mobile/copyright/wikipedia-wordmark-en.svg) ![The Free Encyclopedia](https://en.wikipedia.org/static/images/mobile/copyright/wikipedia-tagline-en.svg) ](https://en.wikipedia.org/wiki/Main_Page)
# [ Search ](https://en.wikipedia.org/wiki/Special:Search "Search Wikipedia \[alt-shift-f\]")
# Search
# Appearance
# Appearance
# move to sidebar hide
# Text
#   * Small
# Standard
# Large
#
# This page always uses small font size
# Width
#   * Standard
# Wide
#
# The content is as wide as possible for your browser window.
# Color (beta)
#   * Automatic
# Light
# Dark
#
# This page is always in light mode.
#   * [Donate](https://donate.wikimedia.org/?wmf_source=donate&wmf_medium=sidebar&wmf_campaign=en.wikipedia.org&uselang=en)
#   * [Create account](https://en.wikipedia.org/w/index.php?title=Special:CreateAccount&returnto=Thangal+Kunju+Musaliar+College+of+Engineering "You are encouraged to create an account and log in; however, it is not mandatory")
#   * [Log in](https://en.wikipedia.org/w/index.php?title=Special:UserLogin&returnto=Thangal+Kunju+Musaliar+College+of+Engineering "You're encouraged to log in; however, it's not mandatory. \[alt-shift-o\]")
#
#
# Personal tools
#   * [Donate](https://donate.wikimedia.org/?wmf_source=donate&wmf_medium=sidebar&wmf_campaign=en.wikipedia.org&uselang=en)
#   * [ Create account](https://en.wikipedia.org/w/index.php?title=Special:CreateAccount&returnto=Thangal+Kunju+Musaliar+College+of+Engineering "You are encouraged to create an account and log in; however, it is not mandatory")
#   * [ Log in](https://en.wikipedia.org/w/index.php?title=Special:UserLogin&returnto=Thangal+Kunju+Musaliar+College+of+Engineering "You're encouraged to log in; however, it's not mandatory. \[alt-shift-o\]")
#
#
# Pages for logged out editors [learn more](https://en.wikipedia.org/wiki/Help:Introduction)
#   * [Contributions](https://en.wikipedia.org/wiki/Special:MyContributions "A list of edits made from this IP address \[alt-shift-y\]")
#   * [Talk](https://en.wikipedia.org/wiki/Special:MyTalk "Discussion about edits from this IP address \[alt-shift-n\]")
#
#
# [ Photograph your local culture, help Wikipedia and win! ](https://commons.wikimedia.org/wiki/Special:MyLanguage/Commons:Wiki_Loves_Folklore_2025)
# [ ![Hide](https://upload.wikimedia.org/wikipedia/commons/2/20/CloseWindow19x19.png)](https://en.wikipedia.org/wiki/Thangal_Kunju_Musaliar_College_of_Engineering "Hide")
# Toggle the table of contents
# ## Contents
# move to sidebar hide
#   * [ (Top) ](https://en.wikipedia.org/wiki/Thangal_Kunju_Musaliar_College_of_Engineering)
#   * [ 1 History ](https://en.wikipedia.org/wiki/Thangal_Kunju_Musaliar_College_of_Engineering#History)
#   * [ 2 Campus ](https://en.wikipedia.org/wiki/Thangal_Kunju_Musaliar_College_of_Engineering#Campus)
#   * [ 3 Organisation and administration ](https://en.wikipedia.org/wiki/Thangal_Kunju_Musaliar_College_of_Engineering#Organisation_and_administration) Toggle Organisation and administration subsection
#     * [ 3.1 Governance ](https://en.wikipedia.org/wiki/Thangal_Kunju_Musaliar_College_of_Engineering#Governance)
#     * [ 3.2 Departments ](https://en.wikipedia.org/wiki/Thangal_Kunju_Musaliar_College_of_Engineering#Departments)
#     * [ 3.3 Facilities ](https://en.wikipedia.org/wiki/Thangal_Kunju_Musaliar_College_of_Engineering#Facilities)
#   * [ 4 Academics ](https://en.wikipedia.org/wiki/Thangal_Kunju_Musaliar_College_of_Engineering
.wikipedia.org/wiki/Wikipedia:File_Upload_Wizard "Upload files \[alt-shift-u\]")
#   * [Permanent link](https://en.wikipedia.org/w/index.php?title=Thangal_Kunju_Musaliar_College_of_Engineering&oldid=1271980861 "Permanent link to this revision of this page")
#   * [Page information](https://en.wikipedia.org/w/index.php?title=Thangal_Kunju_Musaliar_College_of_Engineering&action=info "More information about this page")
#   * [Cite this page](https://en.wikipedia.org/w/index.php?title=Special:CiteThisPage&page=Thangal_Kunju_Musaliar_College_of_Engineering&id=1271980861&wpFormIdentifier=titleform "Information on how to cite this page")
#   * [Get shortened URL](https://en.wikipedia.org/w/index.php?title=Special:UrlShortener&url=https%3A%2F%2Fen.wikipedia.org%2Fwiki%2FThangal_Kunju_Musaliar_College_of_Engineering)
#   * [Download QR code](https://en.wikipedia.org/w/index.php?title=Special:QrCode&url=https%3A%2F%2Fen.wikipedia.org%2Fwiki%2FThangal_Kunju_Musaliar_College_of_Engineering)
#   * [Edit interlanguage links](https://www.wikidata.org/wiki/Special:EntityPage/Q12070837#sitelinks-wikipedia "Edit interlanguage links")
#   * [Expand all](https://en.wikipedia.org/wiki/Thangal_Kunju_Musaliar_College_of_Engineering "Expand all collapsible elements on the current page")
#
#
# Print/export
#   * [Download as PDF](https://en.wikipedia.org/w/index.php?title=Special:DownloadAsPdf&page=Thangal_Kunju_Musaliar_College_of_Engineering&action=show-download-screen "Download this page as a PDF file")
#   * [Printable version](https://en.wikipedia.org/w/index.php?title=Thangal_Kunju_Musaliar_College_of_Engineering&printable=yes "Printable version of this page \[alt-shift-p\]")
#
#
# In other projects
#   * [Wikimedia Commons](https://commons.wikimedia.org/wiki/Category:Thangal_Kunju_Musaliar_College_of_Engineering,_Kollam)
#   * [Wikidata item](https://www.wikidata.org/wiki/Special:EntityPage/Q12070837 "Structured data on this page hosted by Wikidata \[alt-shift-g\]")
#
#
# [Coordinates](https://en.wikipedia.org/wiki/Geographic_coordinate_system "Geographic coordinate system"): ![](https://upload.wikimedia.org/wikipedia/commons/thumb/5/55/WMA_button2b.png/17px-WMA_button2b.png)[8°54′50″N 76°37′57″E﻿ / ﻿8.91389°N 76.63250°E﻿ / 8.91389; 76.63250](https://geohack.toolforge.org/geohack.php?pagename=Thangal_Kunju_Musaliar_College_of_Engineering&params=8_54_50_N_76_37_57_E_)
# From Wikipedia, the free encyclopedia
# Educational institute in Kerala, India
# Thangal Kunju Musaliar College of Engineering (Autonomous)[![](https://upload.wikimedia.org/wikipedia/commons/thumb/1/1f/Thangal_Kunju_Musaliar_College_of_Engineering%2C_Kollam%2C_Kerala.jpg/220px-Thangal_Kunju_Musaliar_College_of_Engineering%2C_Kollam%2C_Kerala.jpg)](https://en.wikipedia.org/wiki/File:Thangal_Kunju_Musaliar_College_of_Engineering,_Kollam,_Kerala.jpg)
# ---
# Type| Government-Aided Autonomous Engineering College
# Established| 3 July 1958; 66 years ago (1958-07-03)
# Founder| Thangal Kunju Musliar
# Affiliation| show Universities (Since 1958)
#   * 1. [APJ Abdul Kalam Technological University](https://en.wikipedia.org/wiki/APJ_Abdul_Kalam_Technological_University "APJ Abdul Kalam Technological University") (Since 2015)
#   * 2. [University of Kerala](https://en.wikipedia.org/wiki/University_of_Kerala "University of Kerala") (1958-2015)
#
#
# [Chairman](https://en.wikipedia.org/wiki/Chairperson "Chairperson")| T. K. Shahal Hassan Musaliar
# [Principal](https://en.wikipedia.org/wiki/Principal_\(academia\) "Principal \(academia\)")| T. A. Shahul Hameed
# Academic staff| 200
# Administrative staff| 500
# Students| 4000
# Location| [Kollam](https://en.wikipedia.org/wiki/Kollam "Kollam"), [Kerala](https://en.wikipedia.org/wiki/Kerala "Kerala"), 691005, India![](https://upload.wikimedia.org/wikipedia/commons/thumb/5/55/WMA_button2b.png/17px-WMA_button2b.png)[8°54′50″N 76°37′57″E﻿ / ﻿8.91389°N 76.63250°E﻿ / 8.91389; 76.63250](https://geohack.toolforge.org/geohack.php?pagename=Thangal_Kunju_Musaliar_College_of_Engineering&params=8_54_50_N_76_37_57_E_)
# Campus| Urban25 acres (100,000 m2)
# Language| English, Malayalam
# Website| [www.tkmce.ac.in](http://www.tkmce.ac.in/)
# [![](https://upload.wikimedia.org/wikipedia/en/thumb/8/87/Thangal_Kunju_Musaliar_College_of_Engineering_logo.png/250px-Thangal_Kunju_Musaliar_College_of_Engineering_logo.png)](https://en.wikipedia.org/wiki/File:Thangal_Kunju_Musaliar_College_of_Engineering_logo.png)
# The **Thangal Kunju Musaliar College of Engineering** , commonly known as **TKMCE** , is the first government-aided engineering institution in the Indian state of [Kerala](https://en.wikipedia.org/wiki/Kerala "Kerala"), with foundation stone laid on 2nd February 1956, and inaugurated on 3 July 1958. The campus is located in [Karicode](https://en.wikipedia.org/wiki/Karicode "Karicode"), approximately 6 kilometres (3.7 mi) away from [Kollam](https://en.wikipedia.org/wiki/Kollam "Kollam"), [Kerala](https://en.wikipedia.org/wiki/Kerala "Kerala"), [India](https://en.wikipedia.org/wiki/India "India"). The college was affiliated to [Kerala University](https://en.wikipedia.org/wiki/Kerala_University "Kerala University") before getting changed to [APJ Abdul Kalam Technological University](https://en.wikipedia.org/wiki/APJ_Abdul_Kalam_Technological_University "APJ Abdul Kalam Technological University") when it was formed in 2015. UGC conferred autonomous status to the institution in 2022.
# ## History
# [[edit](https://en.wikipedia.org/w/index.php?title=Thangal_Kunju_Musaliar_College_of_Engineering&action=edit&section=1 "Edit section: History")]
# [![](https://upload.wikimedia.org/wikipedia/commons/thumb/1/1f/Thangal_Kunju_Musaliar_College_of_Engineering%2C_Kollam%2C_Kerala.jpg/220px-Thangal_Kunju_Musaliar_College_of_Engineering%2C_Kollam%2C_Kerala.jpg)](https://en.wikipedia.org/wiki/File:Thangal_Kunju_Musaliar_College_of_Engineering,_Kollam,_Kerala.jpg)Entrance of Thangal Kunju Musaliar College of Engineering
# The college was founded by the TKM Educational Trust,[[1]](https://en.wikipedia.org/wiki/Thangal_Kunju_Musaliar_College_of_Engineering#cite_note-:0-1) an organization established by [Thangal Kunju Musaliar](https://en.wikipedia.org/wiki/Thangal_Kunju_Musaliar "Thangal Kunju Musaliar"). The college's foundation stone was laid on 3 February 1956 by [Rajendra Prasad](https://en.wikipedia.org/wiki/Rajendra_Prasad "Rajendra Prasad"), the first [President of India](https://en.wikipedia.org/wiki/President_of_India "President of India"), and was inaugurated by [Humayun Kabir](https://en.wikipedia.org/wiki/Humayun_Kabir_\(Bengal_politician\) "Humayun Kabir \(Bengal politician\)"), the Cabinet Minister for Scientific and Cultural Affairs, on 3 July 1958. The institution then went on to become the first government-aided institution in the state of [Kerala](https://en.wikipedia.org/wiki/Kerala "Kerala").
# ## Campus
# [[edit](https://en.wikipedia.org/w/index.php?title=Thangal_Kunju_Musaliar_College_of_Engineering&action=edit&section=2 "Edit section: Campus")]
# [![](https://upload.wikimedia.org/wikipedia/commons/thumb/0/04/T_K_M_Engineering_College.jpg/220px-T_K_M_Engineering_College.jpg)](https://en.wikipedia.org/wiki/File:T_K_M_Engineering_College.jpg)View of Kollam-Punalur Passenger Train passing by the college, near Kilikkollur stop.
# The college is located at Karicode, a suburb town of the coastal city of Kollam on the [Kollam](https://en.wikipedia.org/wiki/Kollam "Kollam")- [Sengottai](https://en.wikipedia.org/wiki/Sengottai "Sengottai") [NH-208](https://en.wikipedia.org/wiki/National_Highway_744_\(India\) "National Highway 744 \(India\)") road. The college is 6 kilometres away from [Kollam](https://en.wikipedia.org/wiki/Kollam "Kollam") city centre (Chinnakada), and 2.2 kilometres from [Kallumthazham](https://en.wikipedia.org/wiki/Kallumthazham "Kallumthazham") junction.
# ## Organisation and administration
# [[edit](https://en.wikipedia.org/w/index.php?title=Thangal_Kunju_Musaliar_College_of_Engineering&action=edit&section=3 "Edit section: Organisation and administration")]
# ### Governance
# [[edit](https://en.wikipedia.org/w/index.php?title=Thangal_Kunju_Musaliar_College_of_Engineering&action=edit&section=4 "Edit section: Governance")]
# The administration of the college is vested in a Governing Body consisting of representatives of the T.K.M College Trust, Govt: Of Kerala, and All India Council for Technical Education. The Governing Body is headed by S.H.Musaliar as Chairman and the Principal as the Ex-officio secretary.
# ### Departments
# [[edit](https://en.wikipedia.org/w/index.php?title=Thangal_Kunju_Musaliar_College_of_Engineering&action=edit&section=5 "Edit section: Departments")]
#   * Dept. of Computer Science and Engineering
#   * Dept. of Electrical and Computer Engineering
#   * Dept. of Electronics and Communication Engineering
#   * Dept. of Electrical and Electronics Engineering
#   * Dept. of Mechanical Engineering
#   * Dept. of Civil Engineering
#   * Dept. of Chemical Engineering
#   * Dept. of Mechanical-Production Engineering
#   * Dept. of Architecture
#   * Dept. of MCA
#   * Dept. of Mathematics
#   * Dept. of Physics
#   * Dept. of Chemistry
#   * Dept. of Economics
#   * Dept. of Physical Education
#   * Center for Artificial Intelligence
#
#
# ### Facilities
# [[edit](https://en.wikipedia.org/w/index.php?title=Thangal_Kunju_Musaliar_College_of_Engineering&action=edit&section=6 "Edit section: Facilities")]
# The college has a central library with over 70,350 books, around 100 technical journals, and periodicals.[[2]](https://en.wikipedia.org/wiki/Thangal_Kunju_Musaliar_College_of_Engineering#cite_note-2)
# ## Academics
# [[edit](https://en.wikipedia.org/w/index.php?title=Thangal_Kunju_Musaliar_College_of_Engineering&action=edit&section=7 "Edit section: Academics")]
# The institute offers BTech programs in eight branches of engineering, five MTech programs and a Computer Applications (MCA) Program.[[3]](https://en.wikipedia.org/wiki/Thangal_Kunju_Musaliar_College_of_Engineering#cite_note-3)
# ### Accreditation and affiliation
# [[edit](https://en.wikipedia.org/w/index.php?title=Thangal_Kunju_Musaliar_College_of_Engineering&action=edit&section=8 "Edit section: Accreditation and affiliation")]
# TKMCE was accredited by the [National Assessment and Accreditation Council](https://en.wikipedia.org/wiki/National_Assessment_and_Accreditation_Council "National Assessment and Accreditation Council") with a validity up to November 2021.[[4]](https://en.wikipedia.org/wiki/Thangal_Kunju_Musaliar_College_of_Engineering#cite_note-4) Ten programmes are approved by the [All India Council for Technical Education](https://en.wikipedia.org/wiki/All_India_Council_for_Technical_Education "All India Council for Technical Education") (AICTE) for 2019–2020,[[5]](https://en.wikipedia.org/wiki/Thangal_Kunju_Musaliar_College_of_Engineering#cite_note-5) some which are accredited by the [National Board of Accreditation](https://en.wikipedia.org/wiki/National_Board_of_Accreditation "National Board of Accreditation") (NBA).[[6]](https://en.wikipedia.org/wiki/Thangal_Kunju_Musaliar_College_of_Engineering#cite_note-6)[[7]](https://en.wikipedia.org/wiki/Thangal_Kunju_Musaliar_College_of_Engineering#cite_note-7) The programmes are affiliated with [APJ Abdul Kalam Technological University](https://en.wikipedia.org/wiki/APJ_Abdul_Kalam_Technological_University "APJ Abdul Kalam Technological University").[[8]](https://en.wikipedia.org/wiki/Thangal_Kunju_Musaliar_College_of_Engineering#cite_note-8)
# ### Admission
# [[edit](https://en.wikipedia.org/w/index.php?title=Thangal_Kunju_Musaliar_College_of_Engineering&action=edit&section=9 "Edit section: Admission")]
#   * Post Graduation
#
#
# Admission to MCA is based on the Kerala LBS Entrance Examination, conducted by the Office of LBS Exams run by the Government of Kerala.[[9]](https://en.wikipedia.org/wiki/Thangal_Kunju_Musaliar_College_of_Engineering#cite_note-mca-9)
# Admission to [MTech](https://en.wikipedia.org/wiki/MTech "MTech") is based on [Graduate Aptitude Test in Engineering](https://en.wikipedia.org/wiki/Graduate_Aptitude_Test_in_Engineering "Graduate Aptitude Test in Engineering") (GATE).[[10]](https://en.wikipedia.org/wiki/Thangal_Kunju_Musaliar_College_of_Engineering#cite_note-gate-10)
#   * Under Graduation Admission to undergraduate courses is based on the [Kerala Engineering Architecture Medical](https://en.wikipedia.org/wiki/Kerala_Engineering_Architecture_Medical "Kerala Engineering Architecture Medical") (KEAM), administered by the [Government of Kerala](https://en.wikipedia.org/wiki/Government_of_Kerala "Government of Kerala"), [India](https://en.wikipedia.org/wiki/India "India").[[11]](https://en.wikipedia.org/wiki/Thangal_Kunju_Musaliar_College_of_Engineering#cite_note-keam-11) Some seats are reserved for students from Arunachal Pradesh, Andaman and Lakshadweep, and also in the management quota.[[12]](https://en.wikipedia.org/wiki/Thangal_Kunju_Musaliar_College_of_Engineering#cite_note-spdc-12)
#
#
#   * PhD candidates are admitted as per [APJ Abdul Kalam Technological University](https://en.wikipedia.org/wiki/APJ_Abdul_Kalam_Technological_University "APJ Abdul Kalam Technological University") norms.[[13]](https://en.wikipedia.org/wiki/Thangal_Kunju_Musaliar_College_of_Engineering#cite_note-13)
#
#
# ### Sports
# [[edit](https://en.wikipedia.org/w/index.php?title=Thangal_Kunju_Musaliar_College_of_Engineering&action=edit&section=10 "Edit section: Sports")]
#   * Football Ground
#   * Cricket Practice Nets
#   * Indoor Badminton Court
#   * Basketball court
#   * Tennis court
#   * Volleyball court
#   * Squash court (under construction)
#
#
# Teams Sent For University Games
#   * Cricket Team
#   * Football Team
#   * Basketball Team
#   * Volleyball Team
#   * Handball Team
#   * Athletics Team
#   * Badminton Team
#   * Tennis Team
#   * Table Tennis Team
#   * Chess Team
#
#
# ## Student life
# [[edit](https://en.wikipedia.org/w/index.php?title=Thangal_Kunju_Musaliar_College_of_Engineering&action=edit&section=11 "Edit section: Student life")]
# ### TEDxTKMCE
# [[edit](https://en.wikipedia.org/w/index.php?title=Thangal_Kunju_Musaliar_College_of_Engineering&action=edit&section=12 "Edit section: TEDxTKMCE")]
# A TEDx event was organised by students of TKMCE, Kollam on 11 August 2018.[[14]](https://en.wikipedia.org/wiki/Thangal_Kunju_Musaliar_College_of_Engineering#cite_note-14) The theme of the event was "Alchemy".
# ## Alumni
# [[edit](https://en.wikipedia.org/w/index.php?title=Thangal_Kunju_Musaliar_College_of_Engineering&action=edit&section=13 "Edit section: Alumni")]
# ![](https://upload.wikimedia.org/wikipedia/en/thumb/f/f2/Edit-clear.svg/40px-Edit-clear.svg.png)| This article's list of alumni **may not follow Wikipedia's[verifiability](https://en.wikipedia.org/wiki/Wikipedia:Verifiability "Wikipedia:Verifiability") policy**. Please [improve this article](https://en.wikipedia.org/w/index.php?title=Thangal_Kunju_Musaliar_College_of_Engineering&action=edit) by removing names that do not have independent [reliable sources](https://en.wikipedia.org/wiki/Wikipedia:Reliable_sources "Wikipedia:Reliable sources") showing they merit inclusion in this article AND are alumni, or by incorporating the relevant publications into the body of the article through appropriate [citations](https://en.wikipedia.org/wiki/Wikipedia:Citing_sources "Wikipedia:Citing sources"). _( August 2019)_
# ---|---
# The alumni association was formed in 1963. It has chapters in various states of India and around the world.[[15]](https://en.wikipedia.org/wiki/Thangal_Kunju_Musaliar_College_of_Engineering#cite_note-15) Notable alumni include:
#   * [Justice Raja Vijayaraghavan V.](https://en.wikipedia.org/wiki/Raja_Vijayaraghavan_V. "Raja Vijayaraghavan V."), Judge, [Kerala High Court](https://en.wikipedia.org/wiki/Kerala_High_Court "Kerala High Court").
#   * [M. Jayachandran](https://en.wikipedia.org/wiki/M._Jayachandran "M. Jayachandran"), [film score](https://en.wikipedia.org/wiki/Film_score "Film score") [composer](https://en.wikipedia.org/wiki/Music_composer "Music composer"), singer, and musician.
#   * [S. Somanath](https://en.wikipedia.org/wiki/S._Somanath "S. Somanath"), Chairman of Indian Space Research Organization (ISRO)[[16]](https://en.wikipedia.org/wiki/Thangal_Kunju_Musaliar_College_of_Engineering#cite_note-16)
#   * [Shibu Baby John](https://en.wikipedia.org/wiki/Shibu_Baby_John "Shibu Baby John"), former Labour Minister of the State Government of Kerala.[[17]](https://en.wikipedia.org/wiki/Thangal_Kunju_Musaliar_College_of_Engineering#cite_note-17)
#   * [T. K. Alex](https://en.wikipedia.org/wiki/T._K._Alex "T. K. Alex"), former director of [Indian Space Research Organisation Satellite Centre](https://en.wikipedia.org/wiki/Indian_Space_Research_Organisation_Satellite_Centre "Indian Space Research Organisation Satellite Centre") (ISAC).
#   * [Suraj Mani](https://en.wikipedia.org/wiki/Suraj_Mani "Suraj Mani"), Indian rock musician.
#
#
# ## See also
# [[edit](https://en.wikipedia.org/w/index.php?title=Thangal_Kunju_Musaliar_College_of_Engineering&action=edit&section
**[^](https://en.wikipedia.org/wiki/Thangal_Kunju_Musaliar_College_of_Engineering#cite_ref-mca_9-0 "Jump up")** ["Official Website for MCA Admission, Kerala"](https://web.archive.org/web/20081025191410/http://www.cee-kerala.org/mca.htm). Archived from [the original](http://www.cee-kerala.org/mca.htm/) on 25 October 2008.
#   10. **[^](https://en.wikipedia.org/wiki/Thangal_Kunju_Musaliar_College_of_Engineering#cite_ref-gate_10-0 "Jump up")** ["GATE Office, IITM"](http://gate.iitm.ac.in/).
#   11. **[^](https://en.wikipedia.org/wiki/Thangal_Kunju_Musaliar_College_of_Engineering#cite_ref-keam_11-0 "Jump up")** ["Official website of the Commissioner for Entrance Exams, Kerala"](http://www.cee-kerala.org/).
#   12. **[^](https://en.wikipedia.org/wiki/Thangal_Kunju_Musaliar_College_of_Engineering#cite_ref-spdc_12-0 "Jump up")** ["The Ministry of Overseas Indian Affairs"](http://moia.gov.in/services.aspx?id1=45&id=m4&idp=45&mainid=23/).[_[permanent dead link](https://en.wikipedia.org/wiki/Wikipedia:Link_rot "Wikipedia:Link rot")_ ‍]
#   13. **[^](https://en.wikipedia.org/wiki/Thangal_Kunju_Musaliar_College_of_Engineering#cite_ref-13 "Jump up")** ["APJ Abdul Kalam Technological University :: Home"](https://ktu.edu.in/eu/core/researchRegulation.htm). _ktu.edu.in_. Retrieved 13 August 2020.
#   14. **[^](https://en.wikipedia.org/wiki/Thangal_Kunju_Musaliar_College_of_Engineering#cite_ref-14 "Jump up")** ["TEDxTKMCE | TED"](https://www.ted.com/tedx/events/30130). _www.ted.com_. Retrieved 27 January 2019.
#   15. **[^](https://en.wikipedia.org/wiki/Thangal_Kunju_Musaliar_College_of_Engineering#cite_ref-15 "Jump up")** ["Alumni Association"](https://tkmce.ac.in/alumni-association.html). TKM College of Engineering. Retrieved 31 October 2019.
#   16. **[^](https://en.wikipedia.org/wiki/Thangal_Kunju_Musaliar_College_of_Engineering#cite_ref-16 "Jump up")** ["Shri. S Somanath assumes charge as Secretary, Department of Space"](https://www.isro.gov.in/update/14-jan-2022/shri-s-somanath-assumes-charge-secretary-department-of-space). _ISRO_. Retrieved 15 January 2022.
#   17. **[^](https://en.wikipedia.org/wiki/Thangal_Kunju_Musaliar_College_of_Engineering#cite_ref-17 "Jump up")** ["Engineering a romance: The Annie and Shibu Baby John love story - The New Indian Express"](https://web.archive.org/web/20131219012536/http://www.newindianexpress.com/cities/kochi/article607951.ece). 19 December 2013. Archived from [the original](http://www.newindianexpress.com/cities/kochi/article607951.ece) on 19 December 2013. Retrieved 3 December 2024.
#
#
# ## External links
# [[edit](https://en.wikipedia.org/w/index.php?title=Thangal_Kunju_Musaliar_College_of_Engineering&action=edit&section=16 "Edit section: External links")]
# [![](https://upload.wikimedia.org/wikipedia/en/thumb/4/4a/Commons-logo.svg/30px-Commons-logo.svg.png)](https://en.wikipedia.org/wiki/File:Commons-logo.svg)
# Wikimedia Commons has media related to [Thangal Kunju Musaliar College of Engineering, Kollam](https://commons.wikimedia.org/wiki/Category:Thangal_Kunju_Musaliar_College_of_Engineering,_Kollam "commons:Category:Thangal Kunju Musaliar College of Engineering, Kollam").
#   * [TKMCE website](http://www.tkmce.ac.in/)
#
#
# hide
#   * [v](https://en.wikipedia.org/wiki/Template:Kollam "Template:Kollam")
#   * [t](https://en.wikipedia.org/wiki/Template_talk:Kollam "Template talk:Kollam")
#   * [e](https://en.wikipedia.org/wiki/Special:EditPage/Template:Kollam "Special:EditPage/Template:Kollam")
#
# [Kollam](https://en.wikipedia.org/wiki/Kollam "Kollam")
# ---
# [History](https://en.wikipedia.org/wiki/History_of_Kollam "History of Kollam")|
#   * [Mar Sapir Iso](https://en.wikipedia.org/wiki/Mar_Sabor_and_Mar_Proth "Mar Sabor and Mar Proth")
#   * [Chera dynasty](https://en.wikipedia.org/wiki/Chera_dynasty "Chera dynasty")
#   * [Port of Quilon](https://en.wikipedia.org/wiki/Kollam_Port "Kollam Port")
#   * [Nelcynda](https://en.wikipedia.org/wiki/Nelcynda "Nelcynda")
#   * [Kollam Era (Malayalam calendar)](https://en.wikipedia.org/wiki/Malayalam_calendar "Malayalam calendar")
#   * [Quilon Syrian (Tharisapalli) plates](https://en.wikipedia.org/wiki/Quilon_Syrian_copper_plates "Quilon Syrian copper plates")
#   * [Venad](https://en.wikipedia.org/wiki/Venad_\(historical_region\) "Venad \(historical region\)")
#   * [Rama Rajasekhara](https://en.wikipedia.org/wiki/Rama_Rajasekhara "Rama Rajasekhara")
#   * [Rama Varma of Venad](https://en.wikipedia.org/wiki/Rama_Varma_of_Venad "Rama Varma of Venad")
#   * [Dutch Malabar](https://en.wikipedia.org/wiki/Dutch_Malabar "Dutch Malabar")
#   * [4th Portuguese India Armada (Gama, 1502)](https://en.wikipedia.org/wiki/4th_Portuguese_India_Armada_\(Gama,_1502\)#Cochin "4th Portuguese India Armada \(Gama, 1502\)")
#   * [Portuguese Cemetery](https://en.wikipedia.org/wiki/Portuguese_Cemetery,_Kollam "Portuguese Cemetery, Kollam")
#   * [Buckingham Canal](https://en.wikipedia.org/wiki/Buckingham_Canal,_Kollam "Buckingham Canal, Kollam")
#   * [St Thomas Fort](https://en.wikipedia.org/wiki/St_Thomas_Fort "St Thomas Fort")
#   * [Kollam Cantonment](https://en.wikipedia.org/wiki/Kollam_Cantonment "Kollam Cantonment")
#   * [Battle of Quilon](https://en.wikipedia.org/wiki/Battle_of_Quilon "Battle of Quilon")
#   * [Roman Catholic Diocese of Quilon](https://en.wikipedia.org/wiki/Roman_Catholic_Diocese_of_Quilon "Roman Catholic Diocese of Quilon")
#   * [Kollam Airport](https://en.wikipedia.org/wiki/Quilon_Aerodrome "Quilon Aerodrome")
#
#
# [Geography](https://en.wikipedia.org/wiki/Geography_of_Kollam "Geography of Kollam")|
#   * [Quilon formation](https://en.wikipedia.org/wiki/Quilon_formation "Quilon formation")
#   * [Ashtamudi Lake](https://en.wikipedia.org/wiki/Ashtamudi_Lake "Ashtamudi Lake")
#   * [Kollam Parappu](https://en.wikipedia.org/wiki/Kollam_Parappu "Kollam Parappu")
#   * [Asramam Maidan](https://en.wikipedia.org/wiki/Asramam_Maidan "Asramam Maidan")
#   * [Estuaries of Paravur](https://en.wikipedia.org/wiki/Estuaries_of_Paravur "Estuaries of Paravur")
#   * [Islands of Kollam](https://en.wikipedia.org/wiki/Islands_of_Kollam "Islands of Kollam")
#   * [Ithikkara River](https://en.wikipedia.org/wiki/Ithikkara_River "Ithikkara River")
#   * [Kallada River](https://en.wikipedia.org/wiki/Kallada_River "Kallada River")
#   * [Kattaka Kayal](https://en.wikipedia.org/wiki/Kattaka_Kayal "Kattaka Kayal")
#   * [Kollam Beach](https://en.wikipedia.org/wiki/Kollam_Beach "Kollam Beach")
#   * [Mundakkal Beach](https://en.wikipedia.org/wiki/Mundakkal_Beach "Mundakkal Beach")
#   * [Vattakkayal](https://en.wikipedia.org/wiki/Vattakkayal "Vattakkayal")
#   * [Paravur Lake](https://en.wikipedia.org/wiki/Paravur_Lake "Paravur Lake")
#   * [Pozhikara](https://en.wikipedia.org/wiki/Pozhikara "Pozhikara")
#   * [Polachira](https://en.wikipedia.org/wiki/Polachira "Polachira")
#   * [Sasthamcotta Lake](https://en.wikipedia.org/wiki/Sasthamcotta_Lake "Sasthamcotta Lake")
#   * [Thirumullavaram Beach](https://en.wikipedia.org/wiki/Thirumullavaram_Beach "Thirumullavaram Beach")
#   * [Thekkumbhagam-Kappil Beach](https://en.wikipedia.org/wiki/Thekkumbhagam "Thekkumbhagam")
#   * [Chittumala Chira](https://en.wikipedia.org/wiki/Chittumala_Chira "Chittumala Chira")
#   * [Ashramam Biodiversity Heritage Site](https://en.wikipedia.org/wiki/Ashramam_Biodiversity_Heritage_Site "Ashramam Biodiversity Heritage Site")
#
#
# Zones|
#   * Central Zone
#   * [Sakthikulangara](https://en.wikipedia.org/wiki/Sakthikulangara "Sakthikulangara")
#   * [Kilikollur](https://en.wikipedia.org/wiki/Kilikollur "Kilikollur")
#   * [Vadakkevila](https://en.wikipedia.org/wiki/Vadakkevila "Vadakkevila")
#   * [Eravipuram](https://en.wikipedia.org/wiki/Eravipuram "Eravipuram")
#   * [Thrikkadavoor](https://en.wikipedia.org/wiki/Thrikkadavoor "Thrikkadavoor")
#
#
# Administration& authorities|
#   * [Kollam Municipal Corporation](https://en.wikipedia.org/wiki/Kollam_Municipal_Corporation "Kollam Municipal Corporation")
#   * [Kollam Development Authority](https://en.wikipedia.org/wiki/Kollam_Development_Authority "Kollam Development Authority")
#   * [Kollam City Police](https://en.wikipedia.org/wiki/Kollam_City_Police "Kollam City Police")
#   * [Kollam Taluk](https://en.wikipedia.org/wiki/Kollam_Taluk "Kollam Taluk")
#   * [Kollam Lok Sabha constituency](https://en.wikipedia.org/wiki/Kollam_\(Lok_Sabha_constituency\) "Kollam \(Lok Sabha constituency\)")
#   * [Kollam Assembly constituency](https://en.wikipedia.org/wiki/Kollam_Assembly_constituency "Kollam Assembly constituency")
#   * [Chavara Assembly constituency](https://en.wikipedia.org/wiki/Chavara_\(State_Assembly_constituency\) "Chavara \(State Assembly constituency\)")
#   * [Eravipuram Assembly constituency](https://en.wikipedia.org/wiki/Eravipuram_\(State_Assembly_constituency\) "Eravipuram \(State Assembly constituency\)")
#
#
# [Economy](https://en.wikipedia.org/wiki/Economy_of_Kollam "Economy of Kollam")|
#   * [Cashew Export Promotion Council of India (CEPCI)](https://en.wikipedia.org/wiki/Cashew_Export_Promotion_Council_of_India "Cashew Export Promotion Council of India")
#   * [Indian Rare Earths Limited (IREL)](https://en.wikipedia.org/wiki/Indian_Rare_Earths "Indian Rare Earths")
#   * [Cashew business in Kollam](https://en.wikipedia.org/wiki/Cashew_business_in_Kollam "Cashew business in Kollam")
#   * [The Kerala Ceramics Limited](https://en.wikipedia.org/wiki/The_Kerala_Ceramics_Limited "The Kerala Ceramics Limited")
#   * [St Thomas Fort](https://en.wikipedia.org/wiki/St_Thomas_Fort "St Thomas Fort")
#   * [Tangasseri Lighthouse](https://en.wikipedia.org/wiki/Tangasseri_Lighthouse "Tangasseri Lighthouse")
#   * [Paravur Thekkumbhagam](https://en.wikipedia.org/wiki/Thekkumbhagam "Thekkumbhagam")
#   * [Thirumullavaram Beach](https://en.wikipedia.org/wiki/Thirumullavaram_Beach "Thirumullavaram Beach")
#   * [Thanni Beach](https://en.wikipedia.org/wiki/Thanni_Beach "Thanni Beach")
#
#
# [Healthcare](https://en.wikipedia.org/wiki/List_of_hospitals_in_Kollam "List of hospitals in Kollam")| | Medical college hospitals|
#   * [Azeezia Medical College Hospital](https://en.wikipedia.org/wiki/Azeezia_Medical_College "Azeezia Medical College")
#   * [Government Medical College, Kollam](https://en.wikipedia.org/wiki/Government_Medical_College,_Kollam "Government Medical College, Kollam")
#   * [Travancore Medicity Medical College](https://en.wikipedia.org/wiki/Travancore_Medical_College_Hospital "Travancore Medical College Hospital")
#
#
# ---|---
#   * [Government District Hospital](https://en.wikipedia.org/wiki/District_Hospital,_Kollam "District Hospital, Kollam")
#   * [Government Victoria Hospital](https://en.wikipedia.org/wiki/Government_Victoria_Hospital,_Kollam "Government Victoria Hospital, Kollam")
#   * [Meditrina Hospital](https://en.wikipedia.org/wiki/Meditrina_Hospital "Meditrina Hospital")
#   * [N. S. Memorial Institute of Medical Sciences](https://en.wikipedia.org/wiki/N._S._Memorial_Institute_of_Medical_Sciences "N. S. Memorial Institute of Medical Sciences")
#   * ESIC Model & Super Speciality Hospital
#   * Upasana Hospital
#   * Shankar's Institute of Medical Science
#   * Dr. Nairs Hospital
#   * Kerala Institute of Medical Sciences
#   * Holy Cross Super Speciality Hospital
#
#
# Buildings& structures|
# * [British Residency](https://en.wikipedia.org/wiki/British_Residency "British Residency")
# * [Cashew House](https://en.wikipedia.org/wiki/Cashew_House "Cashew House")
# * [Cheena Kottaram](https://en.wikipedia.org/wiki/Cheena_Kottaram "Cheena Kottaram")
# * [Crowther Masonic Hall](https://en.wikipedia.org/wiki/Crowther_Masonic_Hall "Crowther Masonic Hall")
# * [Kovilthottam Lighthouse](https://en.wikipedia.org/wiki/Kovilthottam_Lighthouse "Kovilthottam Lighthouse")
# * [SMP Palace](https://en.wikipedia.org/wiki/Sri_Moolam_Thirunal_Palace "Sri Moolam Thirunal Palace")
# * [St Thomas Fort](https://en.wikipedia.org/wiki/St_Thomas_Fort "St Thomas Fort")
# * [Tangasseri Lighthouse](https://en.wikipedia.org/wiki/Tangasseri_Lighthouse "Tangasseri Lighthouse")
# * [Thevally Palace](https://en.wikipedia.org/wiki/Thevally_Palace "Thevally Palace")
# * [The Raviz](https://en.wikipedia.org/wiki/The_Raviz "The Raviz")
# Shopping centres|
#   * [Bishop Jerome Nagar](https://en.wikipedia.org/wiki/Bishop_Jerome_Nagar "Bishop Jerome Nagar")
#   * [Downtown Kollam](https://en.wikipedia.org/wiki/Downtown_Kollam "Downtown Kollam")
#   * [Sree Bhuvaneswari School](https://en.wikipedia.org/wiki/Sree_Bhuvaneswari_School "Sree Bhuvaneswari School")
#   * [Sree Narayana Central School](https://en.wikipedia.org/wiki/Sree_Narayana_Central_School "Sree Narayana Central School")
#   * [Sree Sankara Vidyapeetam](https://en.wikipedia.org/wiki/Sree_Sankara_Vidyapeetam "Sree Sankara Vidyapeetam")
#   * [Sri Atmananda Memorial School (Malakkara, Kerala)](https://en.wikipedia.org/wiki/Sri_Atmananda_Memorial_School_\(Malakkara,_Kerala\) "Sri Atmananda Memorial School \(Malakkara, Kerala\)")
#   * [Sri Sathya Narayana High School](https://en.wikipedia.org/wiki/Sri_Sathya_Narayana_High_School "Sri Sathya Narayana High School")
#   * [SSHSS Katukukke](https://en.wikipedia.org/wiki/SSHSS_Katukukke "SSHSS Katukukke")
#   * SSMVHS School
#   * [St. Joseph's of the Woods EMHS](https://en.wikipedia.org/wiki/St._Joseph%27s_of_the_Woods_EMHS "St. Joseph's of the Woods EMHS")
#   * [Tagore Vidyaniketan Higher Secondary School](https://en.wikipedia.org/wiki/Tagore_Vidyaniketan_Higher_Secondary_School "Tagore Vidyaniketan Higher Secondary School")
#   * [Technical Higher Secondary School, Cherthala](https://en.wikipedia.org/wiki/Technical_Higher_Secondary_School,_Cherthala "Technical Higher Secondary School, Cherthala")
#   * [Technical Higher Secondary School, Vattamkulam](https://en.wikipedia.org/wiki/Technical_Higher_Secondary_School,_Vattamkulam "Technical Higher Secondary School, Vattamkulam")
#   * Technical Higher Secondary School, Vazhakkad
#   * [Udyogamandal School](https://en.wikipedia.org/wiki/Udyogamandal_School "Udyogamandal School")
#   * [Vidyadhiraja Vidya Bhavan Higher Secondary School](https://en.wikipedia.org/wiki/Vidyadhiraja_Vidya_Bhavan_Higher_Secondary_School "Vidyadhiraja Vidya Bhavan Higher Secondary School")
#   * [Vimalagiri Public School](https://en.wikipedia.org/wiki/Vimalagiri_Public_School "Vimalagiri Public School")
#   * [Mookkannoor Govt. Higher Secondary School](https://en.wikipedia.org/wiki/Mookkannoor_Govt._Higher_Secondary_School "Mookkannoor Govt. Higher Secondary School")
#
#
# Research centres|
#   * [Agency for Non-conventional Energy and Rural Technology](https://en.wikipedia.org/wiki/Agency_for_Non-conventional_Energy_and_Rural_Technology "Agency for Non-conventional Energy and Rural Technology")
#   * [Centre for Earth Science Studies](https://en.wikipedia.org/wiki/Centre_for_Earth_Science_Studies "Centre for Earth Science Studies")
#   * [Excise Academy and Research Centre](https://en.wikipedia.org/wiki/Excise_Academy_and_Research_Centre "Excise Academy and Research Centre")
#   * [Free Software Foundation of India](https://en.wikipedia.org/wiki/Free_Software_Foundation_of_India "Free Software Foundation of India")
#   * [Indian Institutes of Science Education and Research](https://en.wikipedia.org/wiki/Indian_Institutes_of_Science_Education_and_Research "Indian Institutes of Science Education and Research")
#   * [Indian Institute of Spices Research](https://en.wikipedia.org/wiki/Indian_Institute_of_Spices_Research "Indian Institute of Spices Research")
load.wikimedia.org/wikipedia/en/thumb/4/41/Flag_of_India.svg/32px-Flag_of_India.svg.png)[India portal](https://en.wikipedia.org/wiki/Portal:India "Portal:India")**
#
#
# Retrieved from "[https://en.wikipedia.org/w/index.php?title=Thangal_Kunju_Musaliar_College_of_Engineering&oldid=1271980861](https://en.wikipedia.org/w/index.php?title=Thangal_Kunju_Musaliar_College_of_Engineering&oldid=1271980861)"
# [Categories](https://en.wikipedia.org/wiki/Help:Category "Help:Category"):
#   * [Engineering colleges in Kollam](https://en.wikipedia.org/wiki/Category:Engineering_colleges_in_Kollam "Category:Engineering colleges in Kollam")
#   * [APJ Abdul Kalam Technological University](https://en.wikipedia.org/wiki/Category:APJ_Abdul_Kalam_Technological_University "Category:APJ Abdul Kalam Technological University")
#   * [Science and technology in Kollam](https://en.wikipedia.org/wiki/Category:Science_and_technology_in_Kollam "Category:Science and technology in Kollam")
#
#
# Hidden categories:
#   * [Pages using gadget WikiMiniAtlas](https://en.wikipedia.org/wiki/Category:Pages_using_gadget_WikiMiniAtlas "Category:Pages using gadget WikiMiniAtlas")
#   * [All articles with dead external links](https://en.wikipedia.org/wiki/Category:All_articles_with_dead_external_links "Category:All articles with dead external links")
#   * [Articles with dead external links from June 2018](https://en.wikipedia.org/wiki/Category:Articles_with_dead_external_links_from_June_2018 "Category:Articles with dead external links from June 2018")
#   * [Articles with permanently dead external links](https://en.wikipedia.org/wiki/Category:Articles_with_permanently_dead_external_links "Category:Articles with permanently dead external links")
#   * [Articles with short description](https://en.wikipedia.org/wiki/Category:Articles_with_short_description "Category:Articles with short description")
#   * [Short description is different from Wikidata](https://en.wikipedia.org/wiki/Category:Short_description_is_different_from_Wikidata "Category:Short description is different from Wikidata")
#   * [Use Indian English from December 2013](https://en.wikipedia.org/wiki/Category:Use_Indian_English_from_December_2013 "Category:Use Indian English from December 2013")
#   * [All Wikipedia articles written in Indian English](https://en.wikipedia.org/wiki/Category:All_Wikipedia_articles_written_in_Indian_English "Category:All Wikipedia articles written in Indian English")
#   * [Use dmy dates from February 2021](https://en.wikipedia.org/wiki/Category:Use_dmy_dates_from_February_2021 "Category:Use dmy dates from February 2021")
#   * [Coordinates on Wikidata](https://en.wikipedia.org/wiki/Category:Coordinates_on_Wikidata "Category:Coordinates on Wikidata")
#   * [Articles using infobox university](https://en.wikipedia.org/wiki/Category:Articles_using_infobox_university "Category:Articles using infobox university")
#   * [Articles needing cleanup from August 2019](https://en.wikipedia.org/wiki/Category:Articles_needing_cleanup_from_August_2019 "Category:Articles needing cleanup from August 2019")
#   * [All pages needing cleanup](https://en.wikipedia.org/wiki/Category:All_pages_needing_cleanup "Category:All pages needing cleanup")
#   * [Commons category link from Wikidata](https://en.wikipedia.org/wiki/Category:Commons_category_link_from_Wikidata "Category:Commons category link from Wikidata")
#
#
#   * This page was last edited on 26 January 2025, at 16:30 (UTC).
#   * Text is available under the [Creative Commons Attribution-ShareAlike 4.0 License](https://en.wikipedia.org/wiki/Wikipedia:Text_of_the_Creative_Commons_Attribution-ShareAlike_4.0_International_License "Wikipedia:Text of the Creative Commons Attribution-ShareAlike 4.0 International License"); additional terms may apply. By using this site, you agree to the [Terms of Use](https://foundation.wikimedia.org/wiki/Special:MyLanguage/Policy:Terms_of_Use "foundation:Special:MyLanguage/Policy:Terms of Use") and [Privacy Policy](https://foundation.wikimedia.org/wiki/Special:MyLanguage/Policy:Privacy_policy "foundation:Special:MyLanguage/Policy:Privacy policy"). Wikipedia® is a registered trademark of the [Wikimedia Foundation, Inc.](https://wikimediafoundation.org/), a non-profit organization.
#
#
#   * [Privacy policy](https://foundation.wikimedia.org/wiki/Special:MyLanguage/Policy:Privacy_policy)
#   * [About Wikipedia](https://en.wikipedia.org/wiki/Wikipedia:About)
#   * [Disclaimers](https://en.wikipedia.org/wiki/Wikipedia:General_disclaimer)
#   * [Contact Wikipedia](https://en.wikipedia.org/wiki/Wikipedia:Contact_us)
#   * [Code of Conduct](https://foundation.wikimedia.org/wiki/Special:MyLanguage/Policy:Universal_Code_of_Conduct)
#   * [Developers](https://developer.wikimedia.org)
#   * [Statistics](https://stats.wikimedia.org/#/en.wikipedia.org)
#   * [Cookie statement](https://foundation.wikimedia.org/wiki/Special:MyLanguage/Policy:Cookie_statement)
#   * [Mobile view](https://en.m.wikipedia.org/w/index.php?title=Thangal_Kunju_Musaliar_College_of_Engineering&mobileaction=toggle_view_mobile)
#   * [Edit preview settings](https://en.wikipedia.org/wiki/Thangal_Kunju_Musaliar_College_of_Engineering)
#
#
#   * [![Wikimedia Foundation](https://en.wikipedia.org/static/images/footer/wikimedia.svg)](https://wikimediafoundation.org/)
#   * [![Powered by MediaWiki](https://en.wikipedia.org/w/resources/assets/mediawiki_compact.svg)](https://www.mediawiki.org/)
#
#
# Search
# Search
# Toggle the table of contents
# Thangal Kunju Musaliar College of Engineering
# [ ](https://en.wikipedia.org/wiki/Thangal_Kunju_Musaliar_College_of_Engineering) [ ](https://en.wikipedia.org/wiki/Thangal_Kunju_Musaliar_College_of_Engineering) [ ](https://en.wikipedia.org/wiki/Thangal_Kunju_Musaliar_College_of_Engineering) [ ](https://en.wikipedia.org/wiki/Thangal_Kunju_Musaliar_College_of_Engineering) [ ](https://en.wikipedia.org/wiki/Thangal_Kunju_Musaliar_College_of_Engineering) [ ](https://en.wikipedia.org/wiki/Thangal_Kunju_Musaliar_College_of_Engineering) [ ](https://en.wikipedia.org/wiki/Thangal_Kunju_Musaliar_College_of_Engineering)
# 2 languages [ Add topic ](https://en.wikipedia.org/wiki/Thangal_Kunju_Musaliar_College_of_Engineering)
# [](https://en.wikipedia.org/wiki/Thangal_Kunju_Musaliar_College_of_Engineering?action=edit)
#   *[v]: View this template
#   *[t]: Discuss this template
#   *[e]: Edit this template
# ...

# %% [markdown]
# ## Introduction to Vector Databases
#
# * <b>Vector stores are specialized data stores that enable indexing and retrieving information based on vector representations.</b>
#
# * <b>A critical advantage of embeddings vectors is they can be compared using many simple mathematical operations:
#
#     - Cosine Similarity: Measures the cosine of the angle between two vectors.
#     - Euclidean Distance: Measures the straight-line distance between two points.
#     - Dot Product: Measures the projection of one vector onto another.
# </b>
#
#
#
# The key methods are:
#
# - add_documents: Add a list of texts to the vector store.
# - delete: Delete a list of documents from the vector store.
# - similarity_search: Search for similar documents to a given query.
#
#
# [documentation](https://python.langchain.com/docs/concepts/vectorstores/)
#
# [list of supported vector databases](https://python.langchain.com/docs/integrations/vectorstores/)

# %%
from langchain_huggingface import HuggingFaceEmbeddings
from langchain_chroma import Chroma


embeddings = HuggingFaceEmbeddings(model_name="sentence-transformers/all-mpnet-base-v2")
vector_store = Chroma(embedding_function=embeddings)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.4k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/571 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/438M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
from langchain_core.documents import Document

document_1 = Document(
    page_content="I had chocalate chip pancakes and scrambled eggs for breakfast this morning.",
    metadata={"source": "tweet"},
)

document_2 = Document(
    page_content="The weather forecast for tomorrow is cloudy and overcast, with a high of 62 degrees.",
    metadata={"source": "news"},
)

documents = [document_1, document_2]
vector_store.add_documents(documents=documents)
# Out:
# ['2cfc804e-65c8-48b0-aee4-b64e2f766104',
#  '10824591-b392-4d3d-ba00-0f1222bd1472']

# %%
vector_store.delete(ids=["0","1"])
# Out:
# WARNING:chromadb.segment.impl.vector.local_hnsw:Delete of nonexisting embedding ID: 0
# WARNING:chromadb.segment.impl.vector.local_hnsw:Delete of nonexisting embedding ID: 1
# WARNING:chromadb.segment.impl.metadata.sqlite:Delete of nonexisting embedding ID: 0
# WARNING:chromadb.segment.impl.metadata.sqlite:Delete of nonexisting embedding ID: 1

# %%
vector_store.similarity_search(
    "PaNcke",
    k=1,
    filter={"source": "tweet"},
)
# Out:
# [Document(id='2cfc804e-65c8-48b0-aee4-b64e2f766104', metadata={'source': 'tweet'}, page_content='I had chocalate chip pancakes and scrambled eggs for breakfast this morning.')]

# %% [markdown]
# https://python.langchain.com/docs/introduction/
